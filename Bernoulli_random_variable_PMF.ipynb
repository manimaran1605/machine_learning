# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def pmf(p,y):
    return p**y * (1-p)**(1-y)

# %%
xrange = np.linspace(0,1,1000)

# %%
sns.displot(pmf(0.25, xrange))
